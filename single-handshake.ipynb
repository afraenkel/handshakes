# %%
% matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import mpl_toolkits.mplot3d as mp3d
# Out:
# Traceback (most recent call last):
#   File "/Users/afraenkel/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 776, in structured_traceback
#     records = _fixed_getinnerframes(etb, context, tb_offset)
#   File "/Users/afraenkel/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 230, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/afraenkel/anaconda/lib/python2.7/site-packages/IPython/core/ultratb.py", line 259, in _fixed_getinnerframes
#     records  = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/inspect.py", line 1044, in getinnerframes
#     framelist.append((tb.tb_frame,) + getframeinfo(tb, context))
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/inspect.py", line 1004, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/inspect.py", line 454, in getsourcefile
#     if hasattr(getmodule(object, filename), '__loader__'):
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/inspect.py", line 483, in getmodule
#     file = getabsfile(object, _filename)
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/inspect.py", line 467, in getabsfile
#     return os.path.normcase(os.path.abspath(_filename))
#   File "/Users/afraenkel/anaconda/python.app/Contents/lib/python2.7/posixpath.py", line 371, in abspath
#     cwd = os.getcwd()
# OSError: [Errno 2] No such file or directory
# ERROR: Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
#
# Unfortunately, your original traceback can not be constructed.
# OSError: [Errno 2] No such file or directory

# %%
import os
from io import BytesIO

# %%
filelist = [ x for x in os.listdir('./') if '.txt' in x ]

# %%
D = dict()
for f in filelist:
    with open(f) as fh:
        s = ''.join([ x for x in fh if (x[0]!='#' and x[0]!='\n')])
        D[f] = pd.read_csv(BytesIO(s),sep=' ',names=['x','y','z','v'],usecols=['x','y','z'])

# %%
fig, axes = plt.subplots(nrows=1, ncols=4,figsize=(20,8))
for i,(k,v) in enumerate(D.items()):
    v.plot(title=k,ax=axes[i])

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig, axes = plt.subplots(nrows=1, ncols=4,figsize=(20,6))

for i,(k,v) in enumerate(D.items()):
    ax = fig.add_subplot(1,4,i,projection='3d')
    ax.plot(v['x'],v['y'],v['z'], label=k)
    ax.legend()

plt.show()

# %%
DFT = dict()
for k,v in D.items():
    a = np.fft.fft(v.as_matrix())
    DFT[k] = map(lambda x: x.real**2+x.imag**2,a)
    DFT[k] = pd.DataFrame(DFT[k])

# %%
fig, axes = plt.subplots(nrows=1, ncols=4,figsize=(20,8))
for i,(k,v) in enumerate(DFT.items()):
    v.plot(title=k,ax=axes[i])

# %%
m,s = D['fistbump.txt'].mean(),D['fistbump.txt'].std()

# %%
def inthresh(x,v):
    m,s = v.mean(),v.std()
    tm,tM = m-s,m+s
    return x>tm and x<tM

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-89946d53861e> in <module>()
# ----> 1 inthresh(2,D['fistbump.txt'])
#
# <ipython-input-140-c238f4fcdb76> in inthresh(x, v)
#       2     m,s = v.mean(),v.std()
#       3     tm,tM = m-s,m+s
# ----> 4     return x>tm and x<tM
#
# /Users/afraenkel/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __nonzero__(self)
#     690         raise ValueError("The truth value of a {0} is ambiguous. "
#     691                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# --> 692                          .format(self.__class__.__name__))
#     693
#     694     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
trunc = D['fistbump.txt'][D['fistbump.txt'].apply(lambda x: x>tM, axis=1).sum(axis=1) != 0]
m_ind,M_ind = trunc.index[0],trunc.index[-1]
D['fistbump.txt'].ix[m_ind:M_ind,:].plot()

# %%
D['fistbump.txt'].plot()
